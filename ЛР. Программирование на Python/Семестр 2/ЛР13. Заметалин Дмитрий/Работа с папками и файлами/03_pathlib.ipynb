# %%
from pathlib import Path

p = Path('.')
a = [x for x in p.iterdir() if x.is_dir()]
print(a)

print(list(p.glob('**/*.pdf')))
# Out:
# []
# [WindowsPath('Работа с папками и файлами (испр).pdf')]

# %% [markdown]
# **pathlib — Object-oriented filesystem paths**
#
# https://docs.python.org/3/library/pathlib.html

# %% [markdown]
# **pathlib — Объектно-ориентированные пути файловой системы**
#
# http://grep.cs.msu.ru/python3.8_RU/digitology.tech/docs/python_3/library/pathlib.html

# %% [markdown]
# **Pathlib — манипуляция путями, создание и удаление папок и файлов**
#
# https://python-scripts.com/pathlib

# %% [markdown]
# **Изучаем Python: модуль pathlib для начинающих с домашним заданием**
#
# https://habr.com/ru/articles/960440/

# %% [markdown]
# **Python Path — Как использовать модуль Pathlib (с примерами)**
#
# https://habr.com/ru/companies/otus/articles/700830/

# %% [markdown]
# **Краткий обзор раздела: Модуль pathlib в Python, операции с путями ОС**
#
# https://docs-python.ru/standart-library/modul-pathlib-python/brief-description/

# %% [markdown]
# **Pathlib в Python: элегантное управление файловой системой без боли**
#
# https://sky.pro/wiki/media/kak-rabotat-s-modulem-pathlib-v-python/
