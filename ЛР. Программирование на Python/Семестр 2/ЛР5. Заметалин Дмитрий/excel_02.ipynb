# %%
import openpyxl

# %%
wb = openpyxl.load_workbook('example.xlsx')

# %%
sheet = wb.active

# %%
print(sheet.title)
# Out:
# 1

# %%
sheet["A1"] = 1
sheet["B1"] = 2
sheet["A2"] = 4
sheet["B2"] = 5
sheet["C1"] = 3
cell = sheet["C2"]
cell.value = 6
sheet["A3"] = "1"
sheet["B3"] = "2"

# %%
type(sheet["C1"].value)
# Out:
# int

# %%
wb.save('example.xlsx')
