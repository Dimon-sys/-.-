# %%
import openpyxl

# %%
wb = openpyxl.load_workbook('example.xlsx')

# %%
sheet = wb.active

# %%
n = sheet.max_row

# %%
m = sheet.max_column

# %%
wb.sheetnames
# Out:
# ['1', 'NewSheet2']

# %%
new_sheet = wb.create_sheet("2")

# %%
wb.sheetnames
# Out:
# ['1', 'NewSheet2', '2']

# %%
sheet1 = wb["1"]

# %%
for row in sheet1.iter_rows(values_only=True):
    print(row)
# Out:
# (1, 2, 3)
# (4, 5, 6)
# ('1', '2', None)
# (7, 8, 9)
# (10, 11, 12)

# %%
sheet2 = wb["2"]

# %%
for row in sheet2.iter_rows(values_only=True):
    print(row)

# %%
sheet2.title = "NewSheet2"

# %%
sheet2['A1'] = 5

# %%
wb.save('example.xlsx')
