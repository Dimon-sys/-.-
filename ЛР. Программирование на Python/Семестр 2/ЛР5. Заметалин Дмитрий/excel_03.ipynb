# %%
import openpyxl

# %%
wb = openpyxl.load_workbook('example.xlsx')

# %%
sheet = wb.active

# %%
print(sheet["A1"])
# Out:
# <Cell '1'.A1>

# %%
print(sheet["A2"].value)
# Out:
# 4

# %%
print(sheet.cell(row=2, column=1))
# Out:
# <Cell '1'.A2>

# %%
print(sheet.cell(row=2, column=1).value)
# Out:
# 4

# %%
type(sheet["A2"].value)
# Out:
# int

# %%
type(sheet["A3"].value)
# Out:
# str

# %%
type(sheet["C3"].value)
# Out:
# NoneType

# %%
sheet.rows
# Out:
# <generator object Worksheet._cells_by_row at 0x0000023E62C0B520>

# %%
list(sheet.rows)
# Out:
# [(<Cell '1'.A1>, <Cell '1'.B1>, <Cell '1'.C1>),
#  (<Cell '1'.A2>, <Cell '1'.B2>, <Cell '1'.C2>),
#  (<Cell '1'.A3>, <Cell '1'.B3>, <Cell '1'.C3>)]

# %%
len(list(sheet.rows))
# Out:
# 3

# %%
print(sheet.max_row)
# Out:
# 3

# %%
sheet.columns
# Out:
# <generator object Worksheet._cells_by_col at 0x0000023E62C0B640>

# %%
list(sheet.columns)
# Out:
# [(<Cell '1'.A1>, <Cell '1'.A2>, <Cell '1'.A3>),
#  (<Cell '1'.B1>, <Cell '1'.B2>, <Cell '1'.B3>),
#  (<Cell '1'.C1>, <Cell '1'.C2>, <Cell '1'.C3>)]

# %%
print(len(list(sheet.columns)))
# Out:
# 3

# %%
sheet.max_column
# Out:
# 3

# %%
sheet["A1:C2"]
# Out:
# ((<Cell '1'.A1>, <Cell '1'.B1>, <Cell '1'.C1>),
#  (<Cell '1'.A2>, <Cell '1'.B2>, <Cell '1'.C2>))

# %%
sheet["A"]
# Out:
# (<Cell '1'.A1>, <Cell '1'.A2>, <Cell '1'.A3>)

# %%
sheet["A:B"]
# Out:
# ((<Cell '1'.A1>, <Cell '1'.A2>, <Cell '1'.A3>),
#  (<Cell '1'.B1>, <Cell '1'.B2>, <Cell '1'.B3>))

# %%
sheet[5]
# Out:
# (<Cell '1'.A5>, <Cell '1'.B5>, <Cell '1'.C5>)

# %%
sheet[5:6]
# Out:
# ((<Cell '1'.A5>, <Cell '1'.B5>, <Cell '1'.C5>),
#  (<Cell '1'.A6>, <Cell '1'.B6>, <Cell '1'.C6>))

# %%
sheet["A4"] = 7
sheet["B4"] = 8
sheet["A5"] = 10
sheet["B5"] = 11
sheet["C4"] = 9
sheet["C5"] = 12

# %%
wb.save('example.xlsx')
