# %%
import openpyxl

# %%
wb = openpyxl.Workbook()

# %%
wb.sheetnames
# Out:
# ['Sheet']

# %%
sheet = wb.active
print(sheet)
print(sheet.title)
# Out:
# <Worksheet "Sheet">
# Sheet

# %%
sheet.title = '1'
print(sheet.title)
# Out:
# 1

# %%
wb.save('example.xlsx')
