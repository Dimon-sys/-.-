# %%
import openpyxl

# %%
wb = openpyxl.load_workbook('example.xlsx')

# %%
sheet = wb.active

# %%
n = sheet.max_row

# %%
m = sheet.max_column

# %%
sheet["B8"] = 'проверка'

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (1, 2, 3)
# (4, 5, 6)
# ('1', '2', None)
# (7, 8, 9)
# (10, 11, 12)
# (None, None, None)
# (None, None, None)
# (None, 'проверка', None)

# %%
sheet.insert_cols(idx=1)

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (None, 1, 2, 3)
# (None, 4, 5, 6)
# (None, '1', '2', None)
# (None, 7, 8, 9)
# (None, 10, 11, 12)
# (None, None, None, None)
# (None, None, None, None)
# (None, None, 'проверка', None)

# %%
sheet.insert_cols(idx=2, amount=3)

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (None, None, None, None, 1, 2, 3)
# (None, None, None, None, 4, 5, 6)
# (None, None, None, None, '1', '2', None)
# (None, None, None, None, 7, 8, 9)
# (None, None, None, None, 10, 11, 12)
# (None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None)
# (None, None, None, None, None, 'проверка', None)

# %%
sheet.delete_cols(idx=1)

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (None, None, None, 1, 2, 3)
# (None, None, None, 4, 5, 6)
# (None, None, None, '1', '2', None)
# (None, None, None, 7, 8, 9)
# (None, None, None, 10, 11, 12)
# (None, None, None, None, None, None)
# (None, None, None, None, None, None)
# (None, None, None, None, 'проверка', None)

# %%
sheet.delete_cols(idx=1, amount=3)

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (1, 2, 3)
# (4, 5, 6)
# ('1', '2', None)
# (7, 8, 9)
# (10, 11, 12)
# (None, None, None)
# (None, None, None)
# (None, 'проверка', None)

# %%
sheet.insert_rows(idx=1)

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (None, None, None)
# (1, 2, 3)
# (4, 5, 6)
# ('1', '2', None)
# (7, 8, 9)
# (10, 11, 12)
# (None, None, None)
# (None, None, None)
# (None, 'проверка', None)

# %%
sheet.insert_rows(idx=4, amount=3)

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (None, None, None)
# (1, 2, 3)
# (4, 5, 6)
# (None, None, None)
# (None, None, None)
# (None, None, None)
# ('1', '2', None)
# (7, 8, 9)
# (10, 11, 12)
# (None, None, None)
# (None, None, None)
# (None, 'проверка', None)

# %%
sheet.delete_rows(idx=1)

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (1, 2, 3)
# (4, 5, 6)
# (None, None, None)
# (None, None, None)
# (None, None, None)
# ('1', '2', None)
# (7, 8, 9)
# (10, 11, 12)
# (None, None, None)
# (None, None, None)
# (None, 'проверка', None)

# %%
sheet.delete_rows(idx=3, amount=3)

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (1, 2, 3)
# (4, 5, 6)
# ('1', '2', None)
# (7, 8, 9)
# (10, 11, 12)
# (None, None, None)
# (None, None, None)
# (None, 'проверка', None)

# %%
sheet.delete_rows(idx=6, amount=3)

# %%
for row in sheet.iter_rows(values_only=True):
    print(row)
# Out:
# (1, 2, 3)
# (4, 5, 6)
# ('1', '2', None)
# (7, 8, 9)
# (10, 11, 12)

# %%
wb.save('example.xlsx')
